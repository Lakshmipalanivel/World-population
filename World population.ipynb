# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
population=pd.read_csv("file:\\\C:/Users/USER/AppData/Local/Temp/Rar$DIa4444.981/world_population.csv")

# %%
population.head()
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia         41128771
# 1   138  ALB         Albania            Tirana    Europe          2842321
# 2    34  DZA         Algeria           Algiers    Africa         44903225
# 3   213  ASM  American Samoa         Pago Pago   Oceania            44273
# 4   203  AND         Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
population.tail()
# Out:
#      Rank CCA3            Country   Capital Continent  2022 Population  \
# 229   226  WLF  Wallis and Futuna  Mata-Utu   Oceania            11572
# 230   172  ESH     Western Sahara  El Aaiún    Africa           575986
# 231    46  YEM              Yemen     Sanaa      Asia         33696614
# 232    63  ZMB             Zambia    Lusaka    Africa         20017675
# 233    74  ZWE           Zimbabwe    Harare    Africa         16320537
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 229            11655            12182            13142            14723
# 230           556048           491824           413296           270375
# 231         32284046         28516545         24743946         18628700
# 232         18927715         16248230         13792086          9891136
# 233         15669666         14154937         12839771         11834676
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
population.rename({'Density (per km²)': 'Density', 'Area (km²)': 'Area','Growth Rate' : 'Growth_Rate', 'World Population Percentage' : 'World_Population_Percentage'}, axis=1, inplace=True)

# %%
population.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                0
# 2020 Population                0
# 2015 Population                0
# 2010 Population                0
# 2000 Population                0
# 1990 Population                0
# 1980 Population                0
# 1970 Population                0
# Area                           0
# Density                        0
# Growth_Rate                    0
# World_Population_Percentage    0
# dtype: int64

# %%
population.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.407441e+07     3.350107e+07     3.172996e+07
# std     67.694165     1.367664e+08     1.355899e+08     1.304050e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.152845e+05     4.046760e+05
# 50%    117.500000     5.559944e+06     5.493074e+06     5.307400e+06
# 75%    175.750000     2.247650e+07     2.144798e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      2.984524e+07     2.626947e+07     2.271022e+07     1.898462e+07
# std       1.242185e+08     1.116982e+08     9.783217e+07     8.178519e+07
# ...

# %%
large_pop = population.nlargest(5, 'Rank')
print(large_pop)
# Out:
#      Rank CCA3           Country       Capital      Continent  \
# 226   234  VAT      Vatican City  Vatican City         Europe
# 209   233  TKL           Tokelau      Nukunonu        Oceania
# 150   232  NIU              Niue         Alofi        Oceania
# 64    231  FLK  Falkland Islands       Stanley  South America
# 137   230  MSR        Montserrat        Brades  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 226              510              520              564              596
# 209             1871             1827             1454             1367
# 150             1934             1942             1847             1812
# 64              3780             3747             3408             3187
# 137             4390             4500             5059             4938
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 226              651              700              733              752
# ...

# %%
top_count = population.nlargest(5, 'World_Population_Percentage')
print(top_count)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41        1425887337       1424929781       1393715448       1348191368
# 92        1417173173       1396387127       1322866505       1240613620
# 221        338289857        335942003        324607776        311182845
# 93         275501339        271857970        259091970        244016173
# 156        235824862        227196741        210969298        194454498
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 41        1264099069       1153704252        982372466        822534450
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(population.corr(),annot=True)
plt.title('Heatmap of Variable Correlations')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.distplot(population['Density'])
plt.title('Distribution of Population Density')
plt.xlabel('Population Density')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x='2020 Population',y='2022 Population',data=population)
plt.title('Rank of Population vs Growth Rate')
plt.xlabel('Rank of Population')
plt.ylabel('Growth Rate')
plt.show()

# %%
population.rename({'Density (per km²)': 'Density', 'Area (km²)': 'Area','Growth Rate' : 'Growth_Rate', 'World Population Percentage' : 'World_Population_Percentage'}, axis=1, inplace=True)

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(population.Growth_Rate)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a1b4d47340>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a1b4d478e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a1b4d47190>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a1b4d47e80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a1b4d50190>],
#  'means': []}

# %%
plt.boxplot(population.Area)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a1b4d848b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a1b4d84e50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a1b4d84700>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a1b4d92430>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a1b4d92700>],
#  'means': []}

# %%
plt.hist(population.Area)
# Out:
# (array([217.,  11.,   0.,   0.,   2.,   3.,   0.,   0.,   0.,   1.]),
#  array([1.00000000e+00, 1.70982510e+06, 3.41964920e+06, 5.12947330e+06,
#         6.83929740e+06, 8.54912150e+06, 1.02589456e+07, 1.19687697e+07,
#         1.36785938e+07, 1.53884179e+07, 1.70982420e+07]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(population.Growth_Rate)
# Out:
# (array([ 1.,  0.,  0.,  0.,  8., 88., 95., 39.,  2.,  1.]),
#  array([0.912  , 0.92771, 0.94342, 0.95913, 0.97484, 0.99055, 1.00626,
#         1.02197, 1.03768, 1.05339, 1.0691 ]),
#  <BarContainer object of 10 artists>)

# %%
from pylab import rcParams
import statsmodels.api as sm

# %%
rcParams['figure.figsize'] = 15,10
decomposition = sm.tsa.seasonal_decompose(population['Growth_Rate'],model='additive',period=2)
decomposition.plot()
plt.show()

# %%
decomposition = sm.tsa.seasonal_decompose(population['Area'],model='multiplicative',period=2)
decomposition.plot()
plt.show()

# %%
sns.pairplot(population)

# %%
fig,ax = plt.subplots(figsize = (20,10))
g = sns.boxplot(data = population,x = '2022 Population', y = 'Growth_Rate', ax = ax)
